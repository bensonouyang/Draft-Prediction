# %%
# %load_ext sql

# %%
# %sql sqlite:///df2022.db
# Out:
# 'Connected: @df2022.db'

# %%
import pandas as pd

df = pd.read_csv('data/df2022.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Round', 'DraftNumber', 'PreTeam', 'urlsummary',
#        'PreType', 'GP', 'GS', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OFF', 'DEF', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF'],
#       dtype='object')

# %%
df2022 = df.drop(columns = ['Unnamed: 0','urlsummary'])

# %%
df = pd.read_csv('data/df2021.csv')
df2021 = df.drop(columns = ['Unnamed: 0','urlsummary'])
df = pd.read_csv('data/df2020.csv')
df2020 = df.drop(columns = ['Unnamed: 0','urlsummary'])

# %%
# https://pypi.org/project/ipython-sql/
# persist to turn dataframe into table in database

# %%sql

PERSIST df2022
# Out:
#  * sqlite:///df2022.db
# 'Persisted df2022'

# %%
# %%sql
#
# PERSIST df2021
# Out:
#  * sqlite:///df2022.db
# 'Persisted df2021'

# %%
# %%sql
#
# PERSIST df2020
# Out:
#  * sqlite:///df2022.db
# 'Persisted df2020'

# %%
# %%sql
# SELECT * FROM df2021 UNION ALL SELECT * FROM df2022
# Out:
#  * sqlite:///df2022.db
# Done.
# [(0, 'Cade Cunningham', 1, 1, 'Oklahoma State', 'College', 27.0, 26.0, 35.4, 20.15, 6.48, 14.81, 0.43799999999999994, 2.3, 5.74, 0.4, 4.89, 5.78, 0.846, 0.7, 5.48, 6.19, 3.48, 1.59, 0.78, 4.04, 2.48),
#  (1, 'Jalen Green', 1, 2, 'NBA G League Ignite', 'G League', 15.0, 15.0, 32.0, 17.93, 6.27, 13.6, 0.461, 2.07, 5.67, 0.365, 1.93, 2.33, 0.8290000000000001, 0.53, 3.53, 4.07, 2.8, 1.53, 0.27, 2.67, 1.73),
#  (2, 'Evan Mobley', 1, 3, 'USC', 'College', 33.0, 33.0, 33.8, 16.36, 5.97, 10.33, 0.578, 0.36, 1.21, 0.3, 4.06, 5.85, 0.6940000000000001, 2.73, 5.94, 8.67, 2.39, 0.79, 2.88, 2.24, 1.76),
#  (3, 'Scottie Barnes', 1, 4, 'Florida State', 'College', 24.0, 7.0, 24.7, 10.33, 4.08, 8.12, 0.503, 0.46, 1.67, 0.275, 1.71, 2.75, 0.621, 1.46, 2.54, 4.0, 4.08, 1.46, 0.46, 2.46, 2.17),
# ...
